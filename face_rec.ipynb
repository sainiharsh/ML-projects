# %% [markdown]
# <a href="https://colab.research.google.com/github/sainiharsh/ML-projects/blob/master/face_rec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cmake dlib face_recognition numpy opencv-python
# Out:
# ...
#      |████████████████████████████████| 100.2MB 114kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=e090f3e8fc28fc555a84759478eb4a3cdf75eccf0932941be0ec0ff13c81258b
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/faces
# Out:
# [Errno 2] No such file or directory: '/gdrive/My Drive/faces'
# /content

# %%
ls
# Out:
# sample_data/

# %%
# !pip install face_recognition

# %%
import face_recognition
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("obama.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=425x531 at 0x7F7730086240>

# %%
img = face_recognition.load_image_file("obama.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-86633bde2401> in <module>()
# ----> 1 img = face_recognition.load_image_file("obama.jpg")
#
# /usr/local/lib/python3.6/dist-packages/face_recognition/api.py in load_image_file(file, mode)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'obama.jpg'

# %%
loc = face_recognition.face_locations(image)

# %%
loc
# Out:
# [(56, 259, 163, 151)]

# %%
cv2.rectangle(image,(151,56),(259,163),(255,0,0),2)
cv2.putText(image,"Barak Obama",(259,163),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3fba46c9f07e> in <module>()
# ----> 1 cv2.rectangle(image,(151,56),(259,163),(255,0,0),2)
#       2 cv2.putText(image,"Barak Obama",(259,163),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
#
# NameError: name 'cv2' is not defined

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=425x531 at 0x7F770E663278>

# %%
features = face_recognition.face_landmarks(img)

# %%
features
# Out:
# [{'bottom_lip': [(236, 135),
#    (228, 146),
#    (218, 151),
#    (210, 152),
#    (202, 152),
#    (192, 147),
#    (184, 137),
#    (187, 138),
#    (202, 145),
#    (210, 146),
#    (218, 144),
#    (233, 136)],
#   'chin': [(159, 95),
#    (159, 109),
#    (161, 123),
#    (164, 136),
#    (168, 150),
#    (176, 162),
#    (185, 171),
#    (196, 179),
#    (209, 181),
#    (223, 178),
#    (234, 170),
#    (244, 160),
#    (252, 148),
#    (256, 135),
#    (258, 122),
#    (259, 108),
#    (258, 95)],
#   'left_eye': [(180, 92),
#    (185, 89),
#    (191, 89),
#    (197, 92),
#    (191, 93),
#    (185, 93)],
#   'left_eyebrow': [(168, 89), (174, 82), (184, 78), (194, 78), (203, 81)],
#   'nose_bridge': [(211, 89), (211, 98), (211, 107), (211, 116)],
#   'nose_tip': [(198, 121), (204, 123), (211, 124), (217, 122), (223, 121)],
#   'right_eye': [(225, 92),
#    (230, 89),
#    (236, 89),
#    (242, 92),
#    (236, 92),
#    (230, 92)],
# ...
